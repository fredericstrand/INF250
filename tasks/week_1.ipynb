# %% [markdown]
# # Tasks Week 1

# %%
import matplotlib.pyplot as plt
from skimage import io

filename = "images/fall.tiff"
fall = io.imread(filename)
plt.imshow(fall)

# %%
print(fall.shape)
fall_red = fall[:,:,0]
print(f"max: {fall_red.max()}, min: {fall_red.min()}")
plt.imshow(fall_red, cmap='gray')
plt.show()
# Out:
# (4032, 3024, 3)
# max: 255, min: 3
